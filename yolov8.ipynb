# %%
import os
import scipy.io
import numpy as np

def process_crowd_data(dataset_root_path):
    ground_truth_dir = os.path.join(dataset_root_path, 'ground_truth')
    formatted_dir = os.path.join(dataset_root_path, 'formatted')

    os.makedirs(formatted_dir, exist_ok=True)
    print(f"Ensured output directory exists: {formatted_dir}\n")

    if not os.path.exists(ground_truth_dir):
        print(f"Error: Ground truth directory not found: {ground_truth_dir}")
        print("Please ensure the path is correct and 'ground_truth' folder exists within your dataset root.")
        return

    mat_files = [f for f in os.listdir(ground_truth_dir) if f.endswith('.mat')]
    if not mat_files:
        print(f"No .mat files found in: {ground_truth_dir}")
        return

    print(f"Found {len(mat_files)} .mat files to process.")

    processed_count = 0
    failed_count = 0

    for filename in mat_files:
        mat_filepath = os.path.join(ground_truth_dir, filename)
        print(f"\nProcessing: {filename}")

        try:
            mat_contents = scipy.io.loadmat(mat_filepath)

            if 'image_info' in mat_contents:
                coordinates = mat_contents['image_info'][0,0][0,0][0]

                if isinstance(coordinates, np.ndarray) and coordinates.ndim == 2 and coordinates.shape[1] == 2:
                    print(f"   Successfully extracted coordinates.")
                    print(f"   Coordinates shape: {coordinates.shape}, Dtype: {coordinates.dtype}")

                    base_name = os.path.splitext(filename)[0]
                    output_name = base_name.replace('GT_', '')
                    output_filename = f"{output_name}.npy"
                    output_filepath = os.path.join(formatted_dir, output_filename)

                    np.save(output_filepath, coordinates)
                    print(f"   Saved coordinates to: {output_filepath}")
                    processed_count += 1
                else:
                    print(f"   Warning: Extracted 'image_info' content is not a (N, 2) NumPy array as expected.")
                    print(f"   Type: {type(coordinates)}, Shape: {getattr(coordinates, 'shape', 'N/A')}")
                    print(f"   This file might not contain coordinates in the expected format after indexing.")
                    failed_count += 1

            else:
                print(f"   Error: 'image_info' key not found in {filename}.")
                failed_count += 1

        except FileNotFoundError:
            print(f"   Error: File not found {mat_filepath}. Skipping.")
            failed_count += 1
        except KeyError as e:
            print(f"   Error: Missing key or invalid access during loading {filename}: {e}")
            print(f"   Please double-check the structure of your .mat file, especially the 'image_info' key.")
            failed_count += 1
        except IndexError as e:
            print(f"   Error: Indexing failed for {filename} with provided [0,0][0,0][0] path: {e}")
            print(f"   The nested structure might be different than expected for this specific file.")
            failed_count += 1
        except Exception as e:
            print(f"   An unexpected error occurred while processing {filename}: {e}")
            failed_count += 1

    print(f"\n--- Processing Summary ---")
    print(f"Total .mat files found: {len(mat_files)}")
    print(f"Successfully processed: {processed_count}")
    print(f"Failed to process: {failed_count}")
    print(f"Formatted coordinates saved to: {formatted_dir}")


dataset_base_path = "/content/crowd_wala_dataset/train_data"

process_crowd_data(dataset_base_path)
# Out:
# Ensured output directory exists: /content/crowd_wala_dataset/train_data/formatted
#
# Found 400 .mat files to process.
#
# Processing: GT_IMG_45.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (30, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_45.npy
#
# Processing: GT_IMG_116.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (168, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_116.npy
#
# Processing: GT_IMG_302.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (82, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_302.npy
#
# Processing: GT_IMG_104.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (31, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_104.npy
#
# Processing: GT_IMG_212.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (111, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_212.npy
#
# Processing: GT_IMG_103.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (151, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_103.npy
#
# Processing: GT_IMG_135.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (42, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_135.npy
#
# Processing: GT_IMG_388.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (137, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_388.npy
#
# Processing: GT_IMG_260.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (162, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_260.npy
#
# Processing: GT_IMG_365.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (75, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_365.npy
#
# Processing: GT_IMG_42.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (43, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_42.npy
#
# Processing: GT_IMG_252.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (83, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_252.npy
#
# Processing: GT_IMG_345.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (78, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_345.npy
#
# Processing: GT_IMG_92.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (36, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_92.npy
#
# Processing: GT_IMG_233.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (23, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_233.npy
#
# Processing: GT_IMG_230.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (142, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_230.npy
#
# Processing: GT_IMG_335.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (23, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_335.npy
#
# Processing: GT_IMG_94.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (29, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_94.npy
#
# Processing: GT_IMG_174.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (174, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_174.npy
#
# Processing: GT_IMG_213.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (36, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_213.npy
#
# Processing: GT_IMG_170.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (150, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_170.npy
#
# Processing: GT_IMG_71.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (35, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_71.npy
#
# Processing: GT_IMG_312.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (114, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_312.npy
#
# Processing: GT_IMG_215.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (85, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_215.npy
#
# Processing: GT_IMG_93.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (20, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_93.npy
#
# Processing: GT_IMG_162.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (301, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_162.npy
#
# Processing: GT_IMG_342.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (157, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_342.npy
#
# Processing: GT_IMG_225.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (80, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_225.npy
#
# Processing: GT_IMG_7.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (118, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_7.npy
#
# Processing: GT_IMG_228.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (118, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_228.npy
#
# Processing: GT_IMG_78.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (43, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_78.npy
#
# Processing: GT_IMG_321.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (167, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_321.npy
#
# Processing: GT_IMG_166.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (103, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_166.npy
#
# Processing: GT_IMG_181.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (108, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_181.npy
#
# Processing: GT_IMG_257.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (204, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_257.npy
#
# Processing: GT_IMG_331.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (341, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_331.npy
#
# Processing: GT_IMG_343.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (264, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_343.npy
#
# Processing: GT_IMG_47.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (94, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_47.npy
#
# Processing: GT_IMG_200.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (299, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_200.npy
#
# Processing: GT_IMG_316.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (35, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_316.npy
#
# Processing: GT_IMG_144.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (26, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_144.npy
#
# Processing: GT_IMG_18.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (178, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_18.npy
#
# Processing: GT_IMG_272.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (198, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_272.npy
#
# Processing: GT_IMG_364.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (257, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_364.npy
#
# Processing: GT_IMG_13.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (118, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_13.npy
#
# Processing: GT_IMG_297.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (274, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_297.npy
#
# Processing: GT_IMG_217.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (78, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_217.npy
#
# Processing: GT_IMG_19.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (43, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_19.npy
#
# Processing: GT_IMG_269.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (146, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_269.npy
#
# Processing: GT_IMG_167.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (205, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_167.npy
#
# Processing: GT_IMG_100.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (206, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_100.npy
#
# Processing: GT_IMG_50.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (185, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_50.npy
#
# Processing: GT_IMG_46.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (87, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_46.npy
#
# Processing: GT_IMG_156.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (87, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_156.npy
#
# Processing: GT_IMG_73.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (41, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_73.npy
#
# Processing: GT_IMG_60.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (40, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_60.npy
#
# Processing: GT_IMG_325.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (55, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_325.npy
#
# Processing: GT_IMG_21.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (152, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_21.npy
#
# Processing: GT_IMG_180.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (65, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_180.npy
#
# Processing: GT_IMG_367.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (84, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_367.npy
#
# Processing: GT_IMG_234.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (54, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_234.npy
#
# Processing: GT_IMG_283.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (117, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_283.npy
#
# Processing: GT_IMG_55.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (211, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_55.npy
#
# Processing: GT_IMG_53.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (125, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_53.npy
#
# Processing: GT_IMG_188.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (344, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_188.npy
#
# Processing: GT_IMG_322.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (55, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_322.npy
#
# Processing: GT_IMG_265.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (32, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_265.npy
#
# Processing: GT_IMG_239.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (310, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_239.npy
#
# Processing: GT_IMG_211.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (34, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_211.npy
#
# Processing: GT_IMG_232.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (33, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_232.npy
#
# Processing: GT_IMG_245.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (65, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_245.npy
#
# Processing: GT_IMG_266.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (81, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_266.npy
#
# Processing: GT_IMG_305.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (152, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_305.npy
#
# Processing: GT_IMG_264.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (29, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_264.npy
#
# Processing: GT_IMG_340.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (158, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_340.npy
#
# Processing: GT_IMG_98.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (251, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_98.npy
#
# Processing: GT_IMG_295.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (271, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_295.npy
#
# Processing: GT_IMG_143.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (31, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_143.npy
#
# Processing: GT_IMG_399.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (169, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_399.npy
#
# Processing: GT_IMG_24.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (104, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_24.npy
#
# Processing: GT_IMG_187.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (125, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_187.npy
#
# Processing: GT_IMG_131.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (222, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_131.npy
#
# Processing: GT_IMG_375.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (73, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_375.npy
#
# Processing: GT_IMG_366.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (45, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_366.npy
#
# Processing: GT_IMG_195.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (29, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_195.npy
#
# Processing: GT_IMG_23.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (154, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_23.npy
#
# Processing: GT_IMG_251.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (69, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_251.npy
#
# Processing: GT_IMG_244.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (25, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_244.npy
#
# Processing: GT_IMG_97.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (283, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_97.npy
#
# Processing: GT_IMG_105.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (130, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_105.npy
#
# Processing: GT_IMG_101.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (83, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_101.npy
#
# Processing: GT_IMG_360.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (111, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_360.npy
#
# Processing: GT_IMG_153.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (27, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_153.npy
#
# Processing: GT_IMG_281.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (81, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_281.npy
#
# Processing: GT_IMG_268.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (34, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_268.npy
#
# Processing: GT_IMG_126.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (107, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_126.npy
#
# Processing: GT_IMG_129.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (146, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_129.npy
#
# Processing: GT_IMG_163.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (166, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_163.npy
#
# Processing: GT_IMG_353.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (90, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_353.npy
#
# Processing: GT_IMG_171.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (15, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_171.npy
#
# Processing: GT_IMG_9.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (168, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_9.npy
#
# Processing: GT_IMG_69.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (53, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_69.npy
#
# Processing: GT_IMG_242.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (49, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_242.npy
#
# Processing: GT_IMG_278.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (30, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_278.npy
#
# Processing: GT_IMG_218.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (118, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_218.npy
#
# Processing: GT_IMG_27.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (196, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_27.npy
#
# Processing: GT_IMG_315.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (344, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_315.npy
#
# Processing: GT_IMG_354.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (159, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_354.npy
#
# Processing: GT_IMG_298.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (47, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_298.npy
#
# Processing: GT_IMG_14.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (50, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_14.npy
#
# Processing: GT_IMG_289.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (123, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_289.npy
#
# Processing: GT_IMG_185.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (136, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_185.npy
#
# Processing: GT_IMG_357.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (63, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_357.npy
#
# Processing: GT_IMG_390.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (46, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_390.npy
#
# Processing: GT_IMG_154.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (415, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_154.npy
#
# Processing: GT_IMG_243.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (227, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_243.npy
#
# Processing: GT_IMG_221.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (113, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_221.npy
#
# Processing: GT_IMG_86.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (22, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_86.npy
#
# Processing: GT_IMG_250.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (136, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_250.npy
#
# Processing: GT_IMG_63.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (191, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_63.npy
#
# Processing: GT_IMG_22.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (50, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_22.npy
#
# Processing: GT_IMG_276.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (26, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_276.npy
#
# Processing: GT_IMG_303.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (300, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_303.npy
#
# Processing: GT_IMG_190.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (147, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_190.npy
#
# Processing: GT_IMG_133.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (253, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_133.npy
#
# Processing: GT_IMG_226.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (94, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_226.npy
#
# Processing: GT_IMG_34.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (98, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_34.npy
#
# Processing: GT_IMG_227.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (267, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_227.npy
#
# Processing: GT_IMG_189.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (90, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_189.npy
#
# Processing: GT_IMG_235.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_235.npy
#
# Processing: GT_IMG_258.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (102, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_258.npy
#
# Processing: GT_IMG_164.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (122, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_164.npy
#
# Processing: GT_IMG_400.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (62, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_400.npy
#
# Processing: GT_IMG_286.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (130, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_286.npy
#
# Processing: GT_IMG_107.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (117, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_107.npy
#
# Processing: GT_IMG_293.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (23, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_293.npy
#
# Processing: GT_IMG_391.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (89, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_391.npy
#
# Processing: GT_IMG_341.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (68, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_341.npy
#
# Processing: GT_IMG_396.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_396.npy
#
# Processing: GT_IMG_85.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (47, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_85.npy
#
# Processing: GT_IMG_348.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (346, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_348.npy
#
# Processing: GT_IMG_15.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (239, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_15.npy
#
# Processing: GT_IMG_178.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (61, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_178.npy
#
# Processing: GT_IMG_130.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (50, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_130.npy
#
# Processing: GT_IMG_352.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (350, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_352.npy
#
# Processing: GT_IMG_95.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (67, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_95.npy
#
# Processing: GT_IMG_125.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_125.npy
#
# Processing: GT_IMG_62.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (269, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_62.npy
#
# Processing: GT_IMG_145.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (188, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_145.npy
#
# Processing: GT_IMG_387.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (88, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_387.npy
#
# Processing: GT_IMG_229.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (77, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_229.npy
#
# Processing: GT_IMG_64.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (157, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_64.npy
#
# Processing: GT_IMG_334.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (62, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_334.npy
#
# Processing: GT_IMG_194.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (412, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_194.npy
#
# Processing: GT_IMG_332.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (15, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_332.npy
#
# Processing: GT_IMG_259.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (235, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_259.npy
#
# Processing: GT_IMG_363.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (80, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_363.npy
#
# Processing: GT_IMG_319.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (55, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_319.npy
#
# Processing: GT_IMG_267.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (138, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_267.npy
#
# Processing: GT_IMG_255.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (13, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_255.npy
#
# Processing: GT_IMG_224.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (167, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_224.npy
#
# Processing: GT_IMG_210.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (165, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_210.npy
#
# Processing: GT_IMG_204.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (95, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_204.npy
#
# Processing: GT_IMG_49.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (204, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_49.npy
#
# Processing: GT_IMG_324.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (178, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_324.npy
#
# Processing: GT_IMG_79.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (60, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_79.npy
#
# Processing: GT_IMG_33.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (276, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_33.npy
#
# Processing: GT_IMG_40.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (84, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_40.npy
#
# Processing: GT_IMG_165.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (27, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_165.npy
#
# Processing: GT_IMG_337.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (89, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_337.npy
#
# Processing: GT_IMG_271.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (175, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_271.npy
#
# Processing: GT_IMG_313.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (41, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_313.npy
#
# Processing: GT_IMG_317.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (108, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_317.npy
#
# Processing: GT_IMG_179.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (45, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_179.npy
#
# Processing: GT_IMG_378.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (80, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_378.npy
#
# Processing: GT_IMG_140.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (165, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_140.npy
#
# Processing: GT_IMG_35.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (21, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_35.npy
#
# Processing: GT_IMG_216.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (169, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_216.npy
#
# Processing: GT_IMG_358.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (86, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_358.npy
#
# Processing: GT_IMG_10.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (230, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_10.npy
#
# Processing: GT_IMG_311.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (143, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_311.npy
#
# Processing: GT_IMG_336.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (109, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_336.npy
#
# Processing: GT_IMG_66.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (61, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_66.npy
#
# Processing: GT_IMG_284.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (247, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_284.npy
#
# Processing: GT_IMG_314.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (26, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_314.npy
#
# Processing: GT_IMG_113.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (106, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_113.npy
#
# Processing: GT_IMG_202.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (167, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_202.npy
#
# Processing: GT_IMG_355.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (19, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_355.npy
#
# Processing: GT_IMG_58.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (300, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_58.npy
#
# Processing: GT_IMG_122.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (43, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_122.npy
#
# Processing: GT_IMG_139.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (58, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_139.npy
#
# Processing: GT_IMG_356.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (201, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_356.npy
#
# Processing: GT_IMG_279.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (63, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_279.npy
#
# Processing: GT_IMG_4.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (293, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_4.npy
#
# Processing: GT_IMG_36.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (32, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_36.npy
#
# Processing: GT_IMG_176.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (281, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_176.npy
#
# Processing: GT_IMG_48.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (89, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_48.npy
#
# Processing: GT_IMG_309.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (54, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_309.npy
#
# Processing: GT_IMG_158.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (12, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_158.npy
#
# Processing: GT_IMG_77.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (220, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_77.npy
#
# Processing: GT_IMG_169.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (109, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_169.npy
#
# Processing: GT_IMG_68.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (114, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_68.npy
#
# Processing: GT_IMG_203.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (344, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_203.npy
#
# Processing: GT_IMG_75.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (70, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_75.npy
#
# Processing: GT_IMG_198.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (121, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_198.npy
#
# Processing: GT_IMG_184.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (81, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_184.npy
#
# Processing: GT_IMG_173.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (42, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_173.npy
#
# Processing: GT_IMG_220.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (38, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_220.npy
#
# Processing: GT_IMG_380.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (132, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_380.npy
#
# Processing: GT_IMG_377.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (95, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_377.npy
#
# Processing: GT_IMG_237.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (106, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_237.npy
#
# Processing: GT_IMG_141.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (151, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_141.npy
#
# Processing: GT_IMG_119.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (302, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_119.npy
#
# Processing: GT_IMG_330.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (156, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_330.npy
#
# Processing: GT_IMG_121.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (42, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_121.npy
#
# Processing: GT_IMG_263.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (105, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_263.npy
#
# Processing: GT_IMG_393.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (191, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_393.npy
#
# Processing: GT_IMG_67.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (175, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_67.npy
#
# Processing: GT_IMG_372.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (125, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_372.npy
#
# Processing: GT_IMG_241.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (234, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_241.npy
#
# Processing: GT_IMG_262.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (47, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_262.npy
#
# Processing: GT_IMG_274.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (78, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_274.npy
#
# Processing: GT_IMG_351.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (99, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_351.npy
#
# Processing: GT_IMG_54.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (139, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_54.npy
#
# Processing: GT_IMG_246.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (195, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_246.npy
#
# Processing: GT_IMG_359.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (49, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_359.npy
#
# Processing: GT_IMG_347.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (33, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_347.npy
#
# Processing: GT_IMG_31.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (173, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_31.npy
#
# Processing: GT_IMG_26.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (81, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_26.npy
#
# Processing: GT_IMG_16.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (42, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_16.npy
#
# Processing: GT_IMG_191.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (575, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_191.npy
#
# Processing: GT_IMG_294.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (47, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_294.npy
#
# Processing: GT_IMG_108.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (209, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_108.npy
#
# Processing: GT_IMG_124.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (267, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_124.npy
#
# Processing: GT_IMG_123.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (155, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_123.npy
#
# Processing: GT_IMG_389.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (54, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_389.npy
#
# Processing: GT_IMG_90.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (84, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_90.npy
#
# Processing: GT_IMG_288.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (16, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_288.npy
#
# Processing: GT_IMG_149.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (111, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_149.npy
#
# Processing: GT_IMG_89.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (211, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_89.npy
#
# Processing: GT_IMG_120.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_120.npy
#
# Processing: GT_IMG_168.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (243, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_168.npy
#
# Processing: GT_IMG_44.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (156, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_44.npy
#
# Processing: GT_IMG_192.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (64, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_192.npy
#
# Processing: GT_IMG_38.mat
# ...
#   Coordinates shape: (168, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_379.npy
#
# Processing: GT_IMG_61.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_61.npy
#
# Processing: GT_IMG_102.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (27, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_102.npy
#
# Processing: GT_IMG_201.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (30, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_201.npy
#
# Processing: GT_IMG_6.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (36, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_6.npy
#
# Processing: GT_IMG_339.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (35, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_339.npy
#
# Processing: GT_IMG_247.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (143, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_247.npy
#
# Processing: GT_IMG_397.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (62, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_397.npy
#
# Processing: GT_IMG_383.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (51, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_383.npy
#
# Processing: GT_IMG_376.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (50, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_376.npy
#
# Processing: GT_IMG_106.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (134, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_106.npy
#
# Processing: GT_IMG_148.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (282, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_148.npy
#
# Processing: GT_IMG_5.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (96, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_5.npy
#
# Processing: GT_IMG_287.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (121, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_287.npy
#
# Processing: GT_IMG_59.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (25, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_59.npy
#
# Processing: GT_IMG_382.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (85, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_382.npy
#
# Processing: GT_IMG_43.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (266, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_43.npy
#
# Processing: GT_IMG_350.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (28, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_350.npy
#
# Processing: GT_IMG_208.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (168, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_208.npy
#
# Processing: GT_IMG_209.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (74, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_209.npy
#
# Processing: GT_IMG_329.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (136, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_329.npy
#
# Processing: GT_IMG_280.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (359, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_280.npy
#
# Processing: GT_IMG_308.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (161, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_308.npy
#
# Processing: GT_IMG_222.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (578, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_222.npy
#
# Processing: GT_IMG_150.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (102, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_150.npy
#
# Processing: GT_IMG_373.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (23, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_373.npy
#
# Processing: GT_IMG_151.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (161, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_151.npy
#
# Processing: GT_IMG_182.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (106, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_182.npy
#
# Processing: GT_IMG_384.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (85, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_384.npy
#
# Processing: GT_IMG_132.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (118, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_132.npy
#
# Processing: GT_IMG_361.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (165, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_361.npy
#
# Processing: GT_IMG_20.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (90, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_20.npy
#
# Processing: GT_IMG_157.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (261, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_157.npy
#
# Processing: GT_IMG_306.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (143, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_306.npy
#
# Processing: GT_IMG_320.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (148, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_320.npy
#
# Processing: GT_IMG_84.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (34, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_84.npy
#
# Processing: GT_IMG_240.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (68, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_240.npy
#
# Processing: GT_IMG_205.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (103, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_205.npy
#
# Processing: GT_IMG_110.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (31, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_110.npy
#
# Processing: GT_IMG_161.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (49, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_161.npy
#
# Processing: GT_IMG_299.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (59, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_299.npy
#
# Processing: GT_IMG_374.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (131, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_374.npy
#
# Processing: GT_IMG_8.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (99, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_8.npy
#
# Processing: GT_IMG_142.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (146, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_142.npy
#
# Processing: GT_IMG_285.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (27, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_285.npy
#
# Processing: GT_IMG_307.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (107, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_307.npy
#
# Processing: GT_IMG_115.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (72, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_115.npy
#
# Processing: GT_IMG_65.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (115, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_65.npy
#
# Processing: GT_IMG_369.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (145, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_369.npy
#
# Processing: GT_IMG_134.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (152, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_134.npy
#
# Processing: GT_IMG_386.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (159, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_386.npy
#
# Processing: GT_IMG_87.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (38, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_87.npy
#
# Processing: GT_IMG_344.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (71, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_344.npy
#
# Processing: GT_IMG_159.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (136, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_159.npy
#
# Processing: GT_IMG_127.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (53, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_127.npy
#
# Processing: GT_IMG_291.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (109, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_291.npy
#
# Processing: GT_IMG_111.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (146, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_111.npy
#
# Processing: GT_IMG_231.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (415, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_231.npy
#
# Processing: GT_IMG_32.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (56, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_32.npy
#
# Processing: GT_IMG_249.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (60, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_249.npy
#
# Processing: GT_IMG_118.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (59, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_118.npy
#
# Processing: GT_IMG_172.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (143, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_172.npy
#
# Processing: GT_IMG_196.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (33, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_196.npy
#
# Processing: GT_IMG_114.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (88, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_114.npy
#
# Processing: GT_IMG_214.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (205, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_214.npy
#
# Processing: GT_IMG_206.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (47, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_206.npy
#
# Processing: GT_IMG_25.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (166, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_25.npy
#
# Processing: GT_IMG_72.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (234, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_72.npy
#
# Processing: GT_IMG_223.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (347, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_223.npy
#
# Processing: GT_IMG_270.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (55, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_270.npy
#
# Processing: GT_IMG_199.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (120, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_199.npy
#
# Processing: GT_IMG_96.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (304, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_96.npy
#
# Processing: GT_IMG_333.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (33, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_333.npy
#
# Processing: GT_IMG_395.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (63, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_395.npy
#
# Processing: GT_IMG_385.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (58, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_385.npy
#
# Processing: GT_IMG_82.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (30, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_82.npy
#
# Processing: GT_IMG_371.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (108, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_371.npy
#
# Processing: GT_IMG_152.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (41, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_152.npy
#
# Processing: GT_IMG_368.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (130, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_368.npy
#
# Processing: GT_IMG_256.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (53, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_256.npy
#
# Processing: GT_IMG_70.mat
#   Successfully extracted coordinates.
#   Coordinates shape: (72, 2), Dtype: float64
#   Saved coordinates to: /content/crowd_wala_dataset/train_data/formatted/IMG_70.npy
#
# --- Processing Summary ---
# Total .mat files found: 400
# Successfully processed: 400
# Failed to process: 0
# Formatted coordinates saved to: /content/crowd_wala_dataset/train_data/formatted

# %%
import os
import numpy as np
from PIL import Image

def convert_npy_to_yolo_labels(dataset_root_path, fixed_box_width=20, fixed_box_height=40):
    images_dir = os.path.join(dataset_root_path, 'images')
    formatted_npy_dir = os.path.join(dataset_root_path, 'formatted')
    yolo_labels_dir = os.path.join(dataset_root_path, 'yolo_labels')

    os.makedirs(yolo_labels_dir, exist_ok=True)
    print(f"Ensured YOLO label directory exists: {yolo_labels_dir}\n")

    npy_files = [f for f in os.listdir(formatted_npy_dir) if f.endswith('.npy')]
    if not npy_files:
        print(f"No .npy files found in: {formatted_npy_dir}")
        return

    print(f"Found {len(npy_files)} .npy files to convert.")

    for npy_filename in npy_files:
        img_filename_base = os.path.splitext(npy_filename)[0]
        img_filepath = os.path.join(images_dir, f"{img_filename_base}.jpg")
        npy_filepath = os.path.join(formatted_npy_dir, npy_filename)
        label_filepath = os.path.join(yolo_labels_dir, f"{img_filename_base}.txt")

        if not os.path.exists(img_filepath):
            print(f"Warning: Corresponding image not found for {npy_filename} at {img_filepath}. Skipping.")
            continue

        try:
            with Image.open(img_filepath) as img:
                img_width, img_height = img.size

            coordinates = np.load(npy_filepath)

            if coordinates.ndim != 2 or coordinates.shape[1] != 2:
                print(f"Warning: {npy_filename} does not contain (N, 2) coordinates. Skipping.")
                continue

            yolo_lines = []
            for x_abs, y_abs in coordinates:
                x_center_abs = x_abs
                y_center_abs = y_abs

                x_center_norm = x_center_abs / img_width
                y_center_norm = y_center_abs / img_height
                width_norm = fixed_box_width / img_width
                height_norm = fixed_box_height / img_height

                x_center_norm = np.clip(x_center_norm, 0, 1)
                y_center_norm = np.clip(y_center_norm, 0, 1)
                width_norm = np.clip(width_norm, 0, 1)
                height_norm = np.clip(height_norm, 0, 1)

                yolo_lines.append(f"0 {x_center_norm:.6f} {y_center_norm:.6f} {width_norm:.6f} {height_norm:.6f}")

            with open(label_filepath, 'w') as f:
                f.write("\n".join(yolo_lines))
            print(f"   Generated YOLO label: {label_filepath}")

        except Exception as e:
            print(f"   Error processing {npy_filename}: {e}. Skipping.")

    print("\n--- YOLO Label Conversion Complete ---")
    print(f"YOLO format label files are in: {yolo_labels_dir}")
    print("Next, you'll need to split your images and labels into train/val sets and create a data.yaml.")

dataset_path = "/content/crowd_wala_dataset/train_data"

BOX_WIDTH = 20
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_218.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_333.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_240.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_372.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_102.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_189.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_203.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_97.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_119.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_216.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_275.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_101.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_377.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_41.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_247.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_124.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_164.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_386.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_111.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_104.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_14.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_258.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_153.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_197.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_257.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_311.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_357.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_131.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_229.txt
#   Generated YOLO label: /content/crowd_wala_dataset/train_data/yolo_labels/IMG_365.txt
#
# --- YOLO Label Conversion Complete ---
# YOLO format label files are in: /content/crowd_wala_dataset/train_data/yolo_labels
# Next, you'll need to split your images and labels into train/val sets and create a data.yaml.

# %%
import os
import shutil
import random

def split_yolo_dataset(dataset_root_path, val_split_ratio=0.2, seed=42):
    random.seed(seed)

    source_images_dir = os.path.join(dataset_root_path, 'images')
    source_labels_dir = os.path.join(dataset_root_path, 'yolo_labels')

    target_base_labels_dir = os.path.join(dataset_root_path, 'labels')
    target_images_train_dir = os.path.join(source_images_dir, 'train')
    target_images_val_dir = os.path.join(source_images_dir, 'val')
    target_labels_train_dir = os.path.join(target_base_labels_dir, 'train')
    target_labels_val_dir = os.path.join(target_base_labels_dir, 'val')

    os.makedirs(target_images_train_dir, exist_ok=True)
    os.makedirs(target_images_val_dir, exist_ok=True)
    os.makedirs(target_labels_train_dir, exist_ok=True)
    os.makedirs(target_labels_val_dir, exist_ok=True)

    print(f"Dataset root: {dataset_root_path}")
    print(f"Source images: {source_images_dir}")
    print(f"Source labels: {source_labels_dir}")
    print(f"Target images train: {target_images_train_dir}")
    print(f"Target images val: {target_images_val_dir}")
    print(f"Target labels train: {target_labels_train_dir}")
    print(f"Target labels val: {target_labels_val_dir}\n")

    all_image_files = [f for f in os.listdir(source_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')) and not os.path.isdir(os.path.join(source_images_dir, f))]

    all_image_files = [f for f in all_image_files if f not in ['train', 'val']]

    if not all_image_files:
        print(f"No image files found in {source_images_dir}. Please ensure images are directly in this folder.")
        return

    print(f"Found {len(all_image_files)} image files to split.")

    random.shuffle(all_image_files)

    num_val = int(len(all_image_files) * val_split_ratio)

    if len(all_image_files) < 2:
        print("Warning: Not enough images to split. All images will be placed in the training set.")
        train_files = all_image_files
        val_files = []
    elif num_val == 0:
        if len(all_image_files) > 0:
            print("Warning: Validation split ratio is too small for the number of images. Setting at least one validation image.")
            num_val = 1
        train_files = all_image_files[num_val:]
        val_files = all_image_files[:num_val]
    elif num_val == len(all_image_files):
        print("Warning: Validation split ratio is too high. Setting at least one training image.")
        num_val = len(all_image_files) - 1
        train_files = all_image_files[num_val:]
        val_files = all_image_files[:num_val]
    else:
        train_files = all_image_files[num_val:]
        val_files = all_image_files[:num_val]


    print(f"Splitting into {len(train_files)} training images and {len(val_files)} validation images.")

    def move_files(files_list, target_img_dir, target_lbl_dir):
        for img_filename in files_list:
            base_name = os.path.splitext(img_filename)[0]
            label_filename = f"{base_name}.txt"

            source_img_path = os.path.join(source_images_dir, img_filename)
            source_label_path = os.path.join(source_labels_dir, label_filename)

            target_img_path = os.path.join(target_img_dir, img_filename)
            target_label_path = os.path.join(target_lbl_dir, label_filename)

            try:
                shutil.move(source_img_path, target_img_path)
                if os.path.exists(source_label_path):
                    shutil.move(source_label_path, target_label_path)
                else:
                    print(f"   Warning: Label file {label_filename} not found for image {img_filename}. Skipping label move.")
            except Exception as e:
                print(f"   Error moving {img_filename} or its label: {e}")

    print("\nMoving training files...")
    move_files(train_files, target_images_train_dir, target_labels_train_dir)
    print("Moving validation files...")
    move_files(val_files, target_images_val_dir, target_labels_val_dir)

    print("\n--- Data Splitting Complete ---")
    print("Your dataset is now organized for YOLOv8 training:")
    print(f"   Images: {target_images_train_dir} and {target_images_val_dir}")
    print(f"   Labels: {target_labels_train_dir} and {target_labels_val_dir}")
    print("\nRemember to create your data.yaml file pointing to these new 'train' and 'val' directories for images and labels.")
    print("Example data.yaml content:")
    print(f"""
train: {os.path.relpath(target_images_train_dir, start=os.path.dirname(os.path.dirname(target_images_train_dir)))}
val: {os.path.relpath(target_images_val_dir, start=os.path.dirname(os.path.dirname(target_images_val_dir)))}

nc: 1
names: ['person']
""")

dataset_path_to_split = "/content/crowd_wala_dataset/train_data"

split_yolo_dataset(dataset_path_to_split, val_split_ratio=0.2, seed=42)
# Out:
# Dataset root: /content/crowd_wala_dataset/train_data
# Source images: /content/crowd_wala_dataset/train_data/images
# Source labels: /content/crowd_wala_dataset/train_data/yolo_labels
# Target images train: /content/crowd_wala_dataset/train_data/images/train
# Target images val: /content/crowd_wala_dataset/train_data/images/val
# Target labels train: /content/crowd_wala_dataset/train_data/labels/train
# Target labels val: /content/crowd_wala_dataset/train_data/labels/val
#
# Found 400 image files to split.
# Splitting into 320 training images and 80 validation images.
#
# Moving training files...
# Moving validation files...
#
# --- Data Splitting Complete ---
# Your dataset is now organized for YOLOv8 training:
#   Images: /content/crowd_wala_dataset/train_data/images/train and /content/crowd_wala_dataset/train_data/images/val
#   Labels: /content/crowd_wala_dataset/train_data/labels/train and /content/crowd_wala_dataset/train_data/labels/val
#
# Remember to create your data.yaml file pointing to these new 'train' and 'val' directories for images and labels.
# Example data.yaml content:
#
# # data.yaml in a parent directory relative to images/ and labels/
# # For example, if data.yaml is in /content/crowd_wala_dataset/
# train: images/train # Adjust based on data.yaml location
# val: images/val   # Adjust based on data.yaml location
#
# nc: 1                 # Number of classes (e.g., 1 for 'person')
# names: ['person']     # Class names

# %%
import os

def create_yolo_data_yaml(dataset_main_folder, num_classes, class_names, yaml_filename="data.yaml"):
    yaml_filepath = os.path.join(dataset_main_folder, yaml_filename)

    train_images_path_relative = os.path.join('train_data', 'images', 'train')
    val_images_path_relative = os.path.join('train_data', 'images', 'val')

    yaml_content = f"""
path: {dataset_main_folder}

train: {train_images_path_relative}
val: {val_images_path_relative}

nc: {num_classes}

names: {class_names}
"""
    yaml_content = yaml_content.strip() + "\n"

    try:
        with open(yaml_filepath, 'w') as f:
            f.write(yaml_content)
        print(f"Successfully created '{yaml_filename}' at: {yaml_filepath}")
        print("\nContent of data.yaml:")
        print(yaml_content)
    except Exception as e:
        print(f"Error creating {yaml_filename}: {e}")

dataset_main_folder_path = "/content/crowd_wala_dataset/"

num_classes = 1
class_names = ['person']

create_yolo_data_yaml(dataset_main_folder_path, num_classes, class_names)
# Out:
# Successfully created 'data.yaml' at: /content/crowd_wala_dataset/data.yaml
#
# Content of data.yaml:
# # YOLOv8 Dataset Configuration
# path: /content/crowd_wala_dataset/ # Dataset root directory (optional, can be relative to current working directory during training)
#
# train: train_data/images/train
# val: train_data/images/val
#
# # Number of classes
# nc: 1
#
# # Class names
# names: ['person']

# %%
from ultralytics import YOLO
import os

def finetune_yolov8_model(
    model_name='yolov8n.pt',
    data_yaml_path="/content/crowd_wala_dataset/data.yaml",
    epochs=20,
    imgsz=640,
    batch_size=-1,
    device='cpu',
    optimizer='AdamW',
    lr0=0.001,
    freeze=10
):
    print(f"--- Starting YOLOv8 Finetuning ---")
    print(f"Model: {model_name}")
    print(f"Data YAML: {data_yaml_path}")
    print(f"Epochs: {epochs}")
    print(f"Image Size: {imgsz}")
    print(f"Batch Size: {batch_size}")
    print(f"Device: {device}")


    try:
        model = YOLO(model_name)
        print(f"\nSuccessfully loaded pretrained model: {model_name}")
    except Exception as e:
        print(f"Error loading model {model_name}: {e}")
        print("Please ensure the model name is correct and you have an internet connection to download it, or it's available locally.")
        return

    try:
        if not os.path.exists(data_yaml_path):
            print(f"Error: data.yaml not found at {data_yaml_path}.")
            print("Please ensure the path to your data.yaml file is correct.")
            return

        results = model.train(
            data=data_yaml_path,
            epochs=epochs,
            imgsz=imgsz,
            batch=batch_size,
            device=device,
            optimizer=optimizer,
            lr0=lr0,
            freeze=freeze
        )
        print("\n--- YOLOv8 Finetuning Completed ---")
        print("Training results can be found in the 'runs/detect' directory (or your specified project/name directory).")
        print(f"The best model weights are typically at: {model.trainer.save_dir}/weights/best.pt")

    except Exception as e:
        print(f"An error occurred during training: {e}")
        print("Common issues: Incorrect data.yaml path, GPU memory issues, incompatible data format.")


my_data_yaml_path = "/content/crowd_wala_dataset/data.yaml"

finetune_yolov8_model(
    model_name='yolov8m.pt',
    data_yaml_path=my_data_yaml_path,
    epochs=50,
    imgsz=640,
    batch_size=16,
    device=0,
    optimizer='AdamW',
    lr0=0.001,
    freeze=10
)
# Out:
# --- Starting YOLOv8 Finetuning ---
# Model: yolo11n.pt
# Data YAML: /content/crowd_wala_dataset/data.yaml
# Epochs: 50
# Image Size: 640
# Batch Size: 16
# Device: 0
#
# Successfully loaded pretrained model: yolo11n.pt
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/crowd_wala_dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train7, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train7, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1980.1±287.0 MB/s, size: 145.0 KB)
# train: Scanning /content/crowd_wala_dataset/train_data/labels/train.cache... 320 images, 0 backgrounds, 0 corrupt: 100%|██████████| 320/320 [00:00<?, ?it/s]
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_133.jpg: 2 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_134.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_212.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_263.jpg: 2 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_272.jpg: 2 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_303.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_349.jpg: 3 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_353.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_361.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_370.jpg: 4 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_374.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_55.jpg: 1 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_63.jpg: 3 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_90.jpg: 4 duplicate labels removed
# train: /content/crowd_wala_dataset/train_data/images/train/IMG_99.jpg: 5 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 982.2±689.2 MB/s, size: 152.4 KB)
# val: Scanning /content/crowd_wala_dataset/train_data/labels/val.cache... 80 images, 0 backgrounds, 0 corrupt: 100%|██████████| 80/80 [00:00<?, ?it/s]
# val: /content/crowd_wala_dataset/train_data/images/val/IMG_183.jpg: 8 duplicate labels removed
# val: /content/crowd_wala_dataset/train_data/images/val/IMG_226.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/train_data/images/val/IMG_84.jpg: 1 duplicate labels removed
# Plotting labels to runs/detect/train7/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train7
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      7.17G      3.677      3.377      1.547       2465        640: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.00it/s]
#                    all         80       9948     0.0111     0.0267    0.00569    0.00109
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      9.34G       2.78      2.347      1.146       4262        640: 100%|██████████| 20/20 [00:06<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.77it/s]
#                    all         80       9948     0.0833      0.201     0.0506     0.0167
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.38G      2.649      1.661      1.101       2702        640: 100%|██████████| 20/20 [00:07<00:00,  2.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.72it/s]
#                    all         80       9948       0.12      0.291     0.0851     0.0243
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      8.17G      2.502        1.4       1.07       2879        640: 100%|██████████| 20/20 [00:07<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.81it/s]
#                    all         80       9948      0.207      0.498      0.244     0.0573
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      7.89G      2.544      1.389      1.088       2707        640: 100%|██████████| 20/20 [00:06<00:00,  3.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.84it/s]
#                    all         80       9948     0.0145      0.035     0.0075    0.00143
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.51G      2.343      1.303      1.036       2613        640: 100%|██████████| 20/20 [00:07<00:00,  2.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.74it/s]
#                    all         80       9948      0.205      0.213      0.137     0.0246
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      8.29G      2.325      1.304      1.036       3711        640: 100%|██████████| 20/20 [00:07<00:00,  2.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████|
/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.19it/s]
#                    all         80       9948      0.718      0.623      0.685       0.35
# 50 epochs completed in 0.127 hours.
# Optimizer stripped from runs/detect/train7/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train7/weights/best.pt, 5.5MB
#
# Validating runs/detect/train7/weights/best.pt...
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:06<00:00,  2.14s/it]
#                    all         80       9948      0.718      0.625      0.685       0.35
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/train7
#
# --- YOLOv8 Finetuning Completed ---
# Training results can be found in the 'runs/detect' directory (or your specified project/name directory).
# The best model weights are typically at: runs/detect/train7/weights/best.pt

# %%
import os
import scipy.io
import numpy as np
from PIL import Image
import shutil
import random

def process_mat_files_to_npy(base_data_path):
    ground_truth_dir = os.path.join(base_data_path, 'ground_truth')
    formatted_dir = os.path.join(base_data_path, 'formatted')

    os.makedirs(formatted_dir, exist_ok=True)
    print(f"Ensured output directory exists: {formatted_dir}\n")

    if not os.path.exists(ground_truth_dir):
        print(f"Error: Ground truth directory not found: {ground_truth_dir}")
        print("Please ensure the path is correct and 'ground_truth' folder exists within your base data path.")
        return

    mat_files = [f for f in os.listdir(ground_truth_dir) if f.endswith('.mat')]
    if not mat_files:
        print(f"No .mat files found in: {ground_truth_dir}")
        return

    print(f"Found {len(mat_files)} .mat files to process in {base_data_path}.")

    processed_count = 0
    failed_count = 0

    for filename in mat_files:
        mat_filepath = os.path.join(ground_truth_dir, filename)

        try:
            mat_contents = scipy.io.loadmat(mat_filepath)

            if 'image_info' in mat_contents:
                coordinates = mat_contents['image_info'][0,0][0,0][0]

                if isinstance(coordinates, np.ndarray) and coordinates.ndim == 2 and coordinates.shape[1] == 2:
                    base_name = os.path.splitext(filename)[0]
                    output_name = base_name.replace('GT_', '')
                    output_filename = f"{output_name}.npy"
                    output_filepath = os.path.join(formatted_dir, output_filename)

                    np.save(output_filepath, coordinates)
                    processed_count += 1
                else:
                    print(f"   Warning: Extracted 'image_info' content from {filename} is not a (N, 2) NumPy array. Skipping.")
                    failed_count += 1
            else:
                print(f"   Error: 'image_info' key not found in {filename}. Skipping.")
                failed_count += 1

        except FileNotFoundError:
            print(f"   Error: File not found {mat_filepath}. Skipping.")
            failed_count += 1
        except KeyError as e:
            print(f"   Error: Missing key or invalid access during loading {filename}: {e}. Skipping.")
            failed_count += 1
        except IndexError as e:
            print(f"   Error: Indexing failed for {filename} with provided [0,0][0,0][0] path: {e}. Skipping.")
            failed_count += 1
        except Exception as e:
            print(f"   An unexpected error occurred while processing {filename}: {e}. Skipping.")
            failed_count += 1

    print(f"\n--- Summary for .mat to .npy in {base_data_path} ---")
    print(f"Total .mat files found: {len(mat_files)}")
    print(f"Successfully processed: {processed_count}")
    print(f"Failed to process: {failed_count}")
    print(f"Formatted coordinates saved to: {formatted_dir}")


def convert_npy_to_yolo_labels(base_data_path, fixed_box_width=20, fixed_box_height=40):
    original_images_dir = os.path.join(base_data_path, 'images')
    formatted_npy_dir = os.path.join(base_data_path, 'formatted')
    final_labels_dir = os.path.join(base_data_path, 'labels')

    os.makedirs(final_labels_dir, exist_ok=True)

    print(f"\n--- Starting .npy to YOLO Labels for {base_data_path} ---")
    print(f"Reading NPY from: {formatted_npy_dir}")
    print(f"Saving Labels to: {final_labels_dir}")
    print(f"Using fixed box size: {fixed_box_width}x{fixed_box_height} pixels\n")

    npy_files = [f for f in os.listdir(formatted_npy_dir) if f.endswith('.npy')]
    if not npy_files:
        print(f"No .npy files found in: {formatted_npy_dir}. Skipping label conversion.")
        return

    processed_count = 0
    failed_count = 0

    for npy_filename in npy_files:
        img_filename_base = os.path.splitext(npy_filename)[0]
        img_filename_jpg = f"{img_filename_base}.jpg"

        current_img_filepath = os.path.join(original_images_dir, img_filename_jpg)
        npy_filepath = os.path.join(formatted_npy_dir, npy_filename)
        label_filepath = os.path.join(final_labels_dir, f"{img_filename_base}.txt")

        if not os.path.exists(current_img_filepath):
            print(f"Warning: Corresponding image not found for {npy_filename} at {current_img_filepath}. Skipping.")
            failed_count += 1
            continue

        try:
            with Image.open(current_img_filepath) as img:
                img_width, img_height = img.size

            coordinates = np.load(npy_filepath)

            if coordinates.ndim != 2 or coordinates.shape[1] != 2:
                print(f"Warning: {npy_filename} does not contain (N, 2) coordinates. Skipping.")
                failed_count += 1
                continue

            yolo_lines = []
            for x_abs, y_abs in coordinates:
                x_center_abs = x_abs
                y_center_abs = y_abs

                x_center_norm = x_center_abs / img_width
                y_center_norm = y_abs / img_height
                width_norm = fixed_box_width / img_width
                height_norm = fixed_box_height / img_height

                x_center_norm = np.clip(x_center_norm, 0, 1)
                y_center_norm = np.clip(y_center_norm, 0, 1)
                width_norm = np.clip(width_norm, 0, 1)
                height_norm = np.clip(height_norm, 0, 1)

                yolo_lines.append(f"0 {x_center_norm:.6f} {y_center_norm:.6f} {width_norm:.6f} {height_norm:.6f}")

            with open(label_filepath, 'w') as f:
                f.write("\n".join(yolo_lines))
            processed_count += 1

        except Exception as e:
            print(f"   Error processing {npy_filename}: {e}. Skipping.")
            failed_count += 1

    print(f"\n--- Summary for .npy to YOLO Labels in {base_data_path} ---")
    print(f"Successfully converted: {processed_count}")
    print(f"Failed conversions: {failed_count}")
    print(f"YOLO format label files are in: {final_labels_dir}")


def create_yolo_data_yaml(dataset_main_folder, num_classes, class_names, yaml_filename="data.yaml"):
    yaml_filepath = os.path.join(dataset_main_folder, yaml_filename)

    train_images_path_relative = os.path.join('train_data', 'images', 'train')
    val_images_path_relative = os.path.join('train_data', 'images', 'val')
    test_images_path_relative = os.path.join('test_data', 'images')

    yaml_content = f"""
path: {dataset_main_folder}

train: {train_images_path_relative}
val: {val_images_path_relative}
test: {test_images_path_relative}

nc: {num_classes}

names: {class_names}
"""
    yaml_content = yaml_content.strip() + "\n"

    try:
        with open(yaml_filepath, 'w') as f:
            f.write(yaml_content)
        print(f"\nSuccessfully created '{yaml_filename}' at: {yaml_filepath}")
        print("\nContent of data.yaml:")
        print(yaml_content)
    except Exception as e:
        print(f"Error creating {yaml_filename}: {e}")

DATASET_MAIN_ROOT = "/content/crowd_wala_dataset/"

TEST_DATA_FOLDER = os.path.join(DATASET_MAIN_ROOT, "test_data")

BOX_WIDTH = 20
BOX_HEIGHT = 40

NUM_CLASSES = 1
CLASS_NAMES = ['person']

print("\n========== Processing TEST DATA ==========")
print(f"Working on: {TEST_DATA_FOLDER}")
process_mat_files_to_npy(TEST_DATA_FOLDER)
convert_npy_to_yolo_labels(TEST_DATA_FOLDER, fixed_box_width=BOX_WIDTH, fixed_box_height=BOX_HEIGHT)

print("\n========== Creating data.yaml ==========")
create_yolo_data_yaml(DATASET_MAIN_ROOT, NUM_CLASSES, CLASS_NAMES)

print("\n--- Test Data Preprocessing and data.yaml Creation Completed ---")
print("Your test dataset is now prepared for YOLOv8 testing.")
print("The data.yaml file has been created/updated with the test data path.")
# Out:
# ========== Processing TEST DATA ==========
# Working on: /content/crowd_wala_dataset/test_data
# Ensured output directory exists: /content/crowd_wala_dataset/test_data/formatted
#
# Found 316 .mat files to process in /content/crowd_wala_dataset/test_data.
#
# --- Summary for .mat to .npy in /content/crowd_wala_dataset/test_data ---
# Total .mat files found: 316
# Successfully processed: 316
# Failed to process: 0
# Formatted coordinates saved to: /content/crowd_wala_dataset/test_data/formatted
#
# --- Starting .npy to YOLO Labels for /content/crowd_wala_dataset/test_data ---
# Reading NPY from: /content/crowd_wala_dataset/test_data/formatted
# Saving Labels to: /content/crowd_wala_dataset/test_data/labels
# Using fixed box size: 20x40 pixels
#
#
# --- Summary for .npy to YOLO Labels in /content/crowd_wala_dataset/test_data ---
# Successfully converted: 316
# Failed conversions: 0
# YOLO format label files are in: /content/crowd_wala_dataset/test_data/labels
#
# ========== Creating data.yaml ==========
#
# Successfully created 'data.yaml' at: /content/crowd_wala_dataset/data.yaml
#
# Content of data.yaml:
# # YOLOv8 Dataset Configuration
# path: /content/crowd_wala_dataset/
#
# train: train_data/images/train
# val: train_data/images/val
# test: test_data/images
#
# # Number of classes
# nc: 1
#
# # Class names
# names: ['person']
#
#
# --- Test Data Preprocessing and data.yaml Creation Completed ---
# Your test dataset is now prepared for YOLOv8 testing.
# The data.yaml file has been created/updated with the test data path.

# %%
import os
from ultralytics import YOLO

DATASET_MAIN_ROOT = "/content/crowd_wala_dataset/"
DATA_YAML_PATH = os.path.join(DATASET_MAIN_ROOT, "data.yaml")
FINETUNED_MODEL_PATH = "runs/detect/train7/weights/best.pt"
IMGSZ = 640
DEVICE = 0

# %%
import os
from ultralytics import YOLO

print("\n========== Starting Model Evaluation on Test Set ==========")
print(f"Loading model from: {FINETUNED_MODEL_PATH}")
print(f"Using data configuration from: {DATA_YAML_PATH}")

try:
    model = YOLO(FINETUNED_MODEL_PATH)

    metrics = model.val(
        data=DATA_YAML_PATH,
        imgsz=IMGSZ,
        batch=16,
        device=DEVICE,
        split='test'
    )

    print("\n--- Evaluation Results ---")
    print(f"Metrics object type: {type(metrics)}")
    print(f"mAP50-95: {metrics.box.map}")
    print(f"mAP50: {metrics.box.map50}")
    print(f"mAP75: {metrics.box.map75}")
    print(f"Precision: {metrics.box.mp}")
    print(f"Recall: {metrics.box.mr}")

except FileNotFoundError:
    print(f"Error: Model weights not found at {FINETUNED_MODEL_PATH}. Please check the path.")
except Exception as e:
    print(f"An error occurred during model evaluation: {e}")

print("\n--- Model Evaluation Completed ---")
# Out:
# ========== Starting Model Evaluation on Test Set ==========
# Loading model from: runs/detect/train7/weights/best.pt
# Using data configuration from: /content/crowd_wala_dataset/data.yaml
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2375.8±824.9 MB/s, size: 140.8 KB)
# val: Scanning /content/crowd_wala_dataset/test_data/labels.cache... 316 images, 0 backgrounds, 0 corrupt: 100%|██████████| 316/316 [00:00<?, ?it/s]
# val: /content/crowd_wala_dataset/test_data/images/IMG_109.jpg: 12 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_116.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_123.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_131.jpg: 2 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_138.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_154.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_212.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_219.jpg: 2 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_253.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_314.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_33.jpg: 2 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_55.jpg: 3 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_61.jpg: 1 duplicate labels removed
# val: /content/crowd_wala_dataset/test_data/images/IMG_65.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
#                    all        316      39178      0.737      0.652      0.716       0.37
# Speed: 1.5ms preprocess, 6.0ms inference, 0.0ms loss, 4.7ms postprocess per image
# Results saved to runs/detect/val8
#
# --- Evaluation Results ---
# Metrics object type: <class 'ultralytics.utils.metrics.DetMetrics'>
# mAP50-95: 0.36971871207082374
# mAP50: 0.7159097905349217
# mAP75: 0.3312741170679686
# Precision: 0.7371874470336324
# Recall: 0.6522027668589514
#
# --- Model Evaluation Completed ---
